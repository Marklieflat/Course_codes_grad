# %%
import pandas as pd
import numpy as np
from gurobipy import Model, GRB, quicksum
#Data preprocessing
childcare = pd.read_csv(r'project1_new_datasets\new_child_care.csv')
employment = pd.read_csv(r'project1_new_datasets\new_employment.csv')
income = pd.read_csv(r'project1_new_datasets\new_income.csv')
population = pd.read_csv(r'project1_new_datasets\new_population.csv')
potential_loc = pd.read_csv(r'project1_new_datasets\new_potential_loc.csv')


population = population.iloc[:, :5].drop(['Total'], axis=1)
population['2w-12yrs'] = np.floor(population.iloc[:, 1:].sum(axis=1)*13/15).astype(int)
demand_desert = pd.merge(population, employment, on='zip_code', how = 'outer')
demand_desert = pd.merge(demand_desert, income, on='zip_code', how = 'outer')
demand_desert['high_demand'] = (demand_desert['employment rate'] >= 0.6)|(demand_desert['average income'] <= 60000)
demand_desert['high_demand'] = demand_desert['high_demand'].astype(int)
#Data cleaning
childcare=childcare[childcare['total_capacity']>0].reset_index(drop=True)
childcare_capacity = childcare.groupby('zip_code')[['infant_capacity','toddler_capacity','preschool_capacity','school_age_capacity'
                                                   ,'children_capacity']].sum().reset_index()
childcare_capacity['2w_5yr_cap'] = np.floor(childcare_capacity.iloc[:, 1:4].sum(axis=1)+childcare_capacity['children_capacity']*5/12).astype(int)
childcare_capacity['2w_12yr_cap'] = np.floor(childcare_capacity.iloc[:, 1:6].sum(axis=1)).astype(int)

demand_desert = pd.merge(demand_desert, childcare_capacity, on='zip_code', how = 'outer')

#def classify_desert(row):
#    if row['high_demand'] == 1:
#        return row['2w_12yr_cap'] <= row['2w-12yrs']*0.5
#    else:
#        return row['2w_12yr_cap'] <= row['2w-12yrs']*1/3
#
#demand_desert['desert'] = demand_desert.apply(classify_desert, axis=1).astype(int)

# demand_desert.to_csv(r'project1_new_datasets\demand_desert.csv', index=False)

# %%
#Problem 1
m1=Model("Budgeting")
x={}
y={}
#Decision variables
for i in range(len(childcare)):
    x[1,i]=m1.addVar(vtype=GRB.INTEGER,name=f"new general slots at facility {i}")
    x[2,i]=m1.addVar(vtype=GRB.INTEGER,name=f"new slots for children under 5 at facility {i}")
for j in range(len(demand_desert)):
    y[1,j]=m1.addVar(vtype=GRB.INTEGER,name=f"newly built small facilities in {j}")
    y[2,j]=m1.addVar(vtype=GRB.INTEGER,name=f"newly built medium facilities in {j}")
    y[3,j]=m1.addVar(vtype=GRB.INTEGER,name=f"newly built large facilities in {j}")
#Objective function
m1.setObjective(
    quicksum(65000*y[1,j]+95000*y[2,j]+115000*y[3,j] for j in range(len(demand_desert)))+
        quicksum(200*x[1,i]+300*x[2,i]+20000*((x[1,i]+x[2,i])/childcare["total_capacity"][i])
            for i in range(len(childcare))),GRB.MINIMIZE
)
#Constraints
for i in range(len(childcare)):
    m1.addConstr(x[1,i]+x[2,i]<=0.2*childcare["total_capacity"][i],f"Maximum expansion rate {i}")
    m1.addConstr(childcare["total_capacity"][i]+x[1,i]+x[2,i]<=max(childcare["total_capacity"][i],500),f"Maximum slots {i}")
    m1.addConstr(x[1,i]>=0,f"non-negativity {i}_1")
    m1.addConstr(x[2,i]>=0,f"non-negativity {i}_2")
    
care_reg=childcare.groupby("zip_code")
for j in range(len(demand_desert)):
    m1.addConstr(y[1,j]>=0,f"non-negativity {j}_y_1")
    m1.addConstr(y[2,j]>=0,f"non-negativity {j}_y_2")
    m1.addConstr(y[3,j]>=0,f"non-negativity {j}_y_3")
    jcare=care_reg.get_group(demand_desert.iloc[j,0]).index
    #high demand or not(changing greater than to greater than or equal)
    if demand_desert["high_demand"][j]==1:
        m1.addConstr(demand_desert["2w_12yr_cap"][j]+100*y[1,j]+200*y[2,j]+400*y[3,j]+
                         quicksum(x[1,l]+x[2,l] for l in jcare)>=int(1/2*(demand_desert["2w-12yrs"][j]))+1)
    else:
        m1.addConstr(demand_desert["2w_12yr_cap"][j]+100*y[1,j]+200*y[2,j]+400*y[3,j]+
                         quicksum(x[1,l]+x[2,l] for l in jcare)>=int(1/3*(demand_desert["2w-12yrs"][j]))+1)
    m1.addConstr(demand_desert["2w_5yr_cap"][j]+50*y[1,j]+100*y[2,j]+200*y[3,j]+
                         quicksum(x[2,l] for l in jcare)>=int(2/3*(demand_desert["-5"][j]))+1)
m1.optimize()
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-09
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 64135 rows, 32579 columns and 142002 nonzeros
# Model fingerprint: 0xf1e59749
# Variable types: 0 continuous, 32579 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [2e+02, 1e+05]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-01, 1e+04]
# Found heuristic solution: objective 3.611000e+08
# Presolve removed 61699 rows and 23307 columns
# Presolve time: 0.13s
# Presolved: 2436 rows, 9272 columns, 14275 nonzeros
# Found heuristic solution: objective 3.414887e+08
# Variable types: 0 continuous, 9272 integer (1003 binary)
# Found heuristic solution: objective 3.165964e+08
#
# Root relaxation: objective 3.165640e+08, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3.1656e+08    0    1 3.1660e+08 3.1656e+08  0.01%     -    1s
#
# Cutting planes:
#   MIR: 2
#
# Explored 1 nodes (1 simplex iterations) in 1.20 seconds (0.16 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 3.16596e+08 3.41489e+08 3.611e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.165964134965e+08, best bound 3.165680670905e+08, gap 0.0090%

# %%
if m1.status == GRB.OPTIMAL:
    for i in range(len(childcare)):
        print(f"Expand facility {i} by {x[1,i].x} slots for all and {x[2,i].x} slots for children under the age of 5")
    for j in range(len(demand_desert)):
        print(f"Build {y[1,j].x} small,{y[2,j].x} medium, {y[3,j].x} large facilities in region {demand_desert['zip_code'][j]}")
else:
    print("No optimal solution found")
# Out:
# Expand facility 0 by 0.0 slots for all and 12.0 slots for children under the age of 5
# Expand facility 1 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 2 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 3 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 4 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 5 by 0.0 slots for all and 17.0 slots for children under the age of 5
# Expand facility 6 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 7 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 8 by 0.0 slots for all and 58.0 slots for children under the age of 5
# Expand facility 9 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 10 by 0.0 slots for all and 61.0 slots for children under the age of 5
# Expand facility 11 by 0.0 slots for all and 28.0 slots for children under the age of 5
# Expand facility 12 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 13 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 14 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 15 by 0.0 slots for all and 34.0 slots for children under the age of 5
# Expand facility 16 by 0.0 slots for all and 47.0 slots for children under the age of 5
# Expand facility 17 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 18 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 19 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 20 by 0.0 slots for all and 39.0 slots for children under the age of 5
# Expand facility 21 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 22 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 23 by 0.0 slots for all and 22.0 slots for children under the age of 5
# Expand facility 24 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 25 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 26 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 27 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 28 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 29 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 30 by 0.0 slots for all and 43.0 slots for children under the age of 5
# Expand facility 31 by 0.0 slots for all and 37.0 slots for children under the age of 5
# Expand facility 32 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 33 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 34 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 35 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 36 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 37 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 38 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 39 by 0.0 slots for all and 22.0 slots for children under the age of 5
# Expand facility 40 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 41 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 42 by 0.0 slots for all and 40.0 slots for children under the age of 5
# Expand facility 43 by 0.0 slots for all and 57.0 slots for children under the age of 5
# Expand facility 44 by 0.0 slots for all and 32.0 slots for children under the age of 5
# Expand facility 45 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 46 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 47 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 48 by 0.0 slots for all and 22.0 slots for children under the age of 5
# Expand facility 49 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 50 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 51 by 0.0 slots for all and 44.0 slots for children under the age of 5
# Expand facility 52 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 53 by 0.0 slots for all and 48.0 slots for children under the age of 5
# Expand facility 54 by 0.0 slots for all and 52.0 slots for children under the age of 5
# Expand facility 55 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 56 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 57 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 58 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 59 by 0.0 slots for all and 40.0 slots for children under the age of 5
# Expand facility 60 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 61 by 0.0 slots for all and 31.0 slots for children under the age of 5
# Expand facility 62 by 0.0 slots for all and 28.0 slots for children under the age of 5
# Expand facility 63 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 64 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 65 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 66 by 0.0 slots for all and 43.0 slots for children under the age of 5
# Expand facility 67 by 0.0 slots for all and 37.0 slots for children under the age of 5
# Expand facility 68 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 69 by 0.0 slots for all and 17.0 slots for children under the age of 5
# Expand facility 70 by 0.0 slots for all and 43.0 slots for children under the age of 5
# Expand facility 71 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 72 by 0.0 slots for all and 21.0 slots for children under the age of 5
# Expand facility 73 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 74 by 0.0 slots for all and 39.0 slots for children under the age of 5
# Expand facility 75 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 76 by 0.0 slots for all and 22.0 slots for children under the age of 5
# Expand facility 77 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 78 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 79 by 0.0 slots for all and 4.0 slots for children under the age of 5
# Expand facility 80 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 81 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 82 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 83 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 84 by 0.0 slots for all and 46.0 slots for children under the age of 5
# Expand facility 85 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 86 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 87 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 88 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 89 by 0.0 slots for all and 65.0 slots for children under the age of 5
# Expand facility 90 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 91 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 92 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 93 by 0.0 slots for all and 60.0 slots for children under the age of 5
# Expand facility 94 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 95 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 96 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 97 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 98 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 99 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 100 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 101 by 0.0 slots for all and 32.0 slots for children under the age of 5
# Expand facility 102 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 103 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 104 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 105 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 106 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 107 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 108 by 0.0 slots for all and 80.0 slots for children under the age of 5
# Expand facility 109 by 0.0 slots for all and 76.0 slots for children under the age of 5
# Expand facility 110 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 111 by 0.0 slots for all and 7.0 slots for children under the age of 5
# Expand facility 112 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 113 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 114 by 0.0 slots for all and 2.0 slots for children under the age of 5
# Expand facility 115 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 116 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 117 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 118 by 0.0 slots for all and 28.0 slots for children under the age of 5
# Expand facility 119 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 120 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 121 by 0.0 slots for all and 2.0 slots for children under the age of 5
# Expand facility 122 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 123 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 124 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 125 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 126 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 127 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 128 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 129 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 130 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 131 by 0.0 slots for all and 12.0 slots for children under the age of 5
# Expand facility 132 by 0.0 slots for all and 1.0 slots for children under the age of 5
# Expand facility 133 by 0.0 slots for all and 1.0 slots for children under the age of 5
# Expand facility 134 by 0.0 slots for all and 1.0 slots for children under the age of 5
# Expand facility 135 by 0.0 slots for all and 1.0 slots for children under the age of 5
# Expand facility 136 by 0.0 slots for all and 1.0 slots for children under the age of 5
# Expand facility 137 by 0.0 slots for all and 20.0 slots for children under the age of 5
# Expand facility 138 by 0.0 slots for all and 25.0 slots for children under the age of 5
# Expand facility 139 by 0.0 slots for all and 2.0 slots for children under the age of 5
# Expand facility 140 by 0.0 slots for all and 1.0 slots for children under the age of 5
# Expand facility 141 by 0.0 slots for all and 45.0 slots for children under the age of 5
# Expand facility 142 by 0.0 slots for all and 3.0 slots for children under the age of 5
# Expand facility 143 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 144 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 145 by 0.0 slots for all and 60.0 slots for children under the age of 5
# Expand facility 146 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 147 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 148 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 149 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 150 by 0.0 slots for all and 45.0 slots for children under the age of 5
# Expand facility 151 by 0.0 slots for all and 40.0 slots for children under the age of 5
# Expand facility 152 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 153 by 0.0 slots for all and 14.0 slots for children under the age of 5
# Expand facility 154 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 155 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 156 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 157 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 158 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 159 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 160 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 161 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 162 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 163 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 164 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 165 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 166 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 167 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 168 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 169 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 170 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 171 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 172 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 173 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 174 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 175 by 0.0 slots for all and 27.0 slots for children under the age of 5
# Expand facility 176 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 177 by 0.0 slots for all and 56.0 slots for children under the age of 5
# Expand facility 178 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 179 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 180 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 181 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 182 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 183 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 184 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 185 by 0.0 slots for all and 26.0 slots for children under the age of 5
# Expand facility 186 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 187 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 188 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 189 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 190 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 191 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 192 by 0.0 slots for all and 37.0 slots for children under the age of 5
# Expand facility 193 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 194 by 0.0 slots for all and 39.0 slots for children under the age of 5
# Expand facility 195 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 196 by 0.0 slots for all and 23.0 slots for children under the age of 5
# Expand facility 197 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 198 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 199 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 200 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 201 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 202 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 203 by 0.0 slots for all and 25.0 slots for children under the age of 5
# Expand facility 204 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 205 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 206 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 207 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 208 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 209 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 210 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 211 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 212 by 0.0 slots for all and 39.0 slots for children under the age of 5
# Expand facility 213 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 214 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 215 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 216 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 217 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 218 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 219 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 220 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 221 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 222 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 223 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 224 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 225 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 226 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 227 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 228 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 229 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 230 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 231 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 232 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 233 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 234 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 235 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 236 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 237 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 238 by 0.0 slots for all and 45.0 slots for children under the age of 5
# Expand facility 239 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 240 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 241 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 242 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 243 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 244 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 245 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 246 by 0.0 slots for all and 35.0 slots for children under the age of 5
# Expand facility 247 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 248 by 0.0 slots for all and 27.0 slots for children under the age of 5
# Expand facility 249 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 250 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 251 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 252 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 253 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 254 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 255 by 0.0 slots for all and 30.0 slots for children under the age of 5
# Expand facility 256 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 257 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 258 by 0.0 slots for all and 48.0 slots for children under the age of 5
# Expand facility 259 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 260 by 0.0 slots for all and 57.0 slots for children under the age of 5
# Expand facility 261 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 262 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 263 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 264 by 0.0 slots for all and 27.0 slots for children under the age of 5
# Expand facility 265 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 266 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 267 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 268 by 0.0 slots for all and 35.0 slots for children under the age of 5
# Expand facility 269 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 270 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 271 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 272 by 0.0 slots for all and 17.0 slots for children under the age of 5
# Expand facility 273 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 274 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 275 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 276 by 0.0 slots for all and 29.0 slots for children under the age of 5
# Expand facility 277 by 0.0 slots for all and 24.0 slots for children under the age of 5
# Expand facility 278 by 0.0 slots for all and 28.0 slots for children under the age of 5
# Expand facility 279 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 280 by 0.0 slots for all and 58.0 slots for children under the age of 5
# Expand facility 281 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 282 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 283 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 284 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 285 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 286 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 287 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 288 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 289 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 290 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 291 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 292 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 293 by 0.0 slots for all and 27.0 slots for children under the age of 5
# Expand facility 294 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 295 by 0.0 slots for all and 22.0 slots for children under the age of 5
# Expand facility 296 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 297 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 298 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 299 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 300 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 301 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 302 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 303 by 0.0 slots for all and 28.0 slots for children under the age of 5
# Expand facility 304 by 0.0 slots for all and 23.0 slots for children under the age of 5
# Expand facility 305 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 306 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 307 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 308 by 0.0 slots for all and 51.0 slots for children under the age of 5
# Expand facility 309 by 0.0 slots for all and 15.0 slots for children under the age of 5
# Expand facility 310 by 0.0 slots for all and 19.0 slots for children under the age of 5
# Expand facility 311 by 0.0 slots for all and 11.0 slots for children under the age of 5
# Expand facility 312 by 0.0 slots for all and 39.0 slots for children under the age of 5
# Expand facility 313 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 314 by 0.0 slots for all and 37.0 slots for children under the age of 5
# Expand facility 315 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 316 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 317 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 318 by 0.0 slots for all and 29.0 slots for children under the age of 5
# Expand facility 319 by 0.0 slots for all and 58.0 slots for children under the age of 5
# Expand facility 320 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 321 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 322 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 323 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 324 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 325 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 326 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 327 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 328 by 0.0 slots for all and 32.0 slots for children under the age of 5
# Expand facility 329 by 0.0 slots for all and 20.0 slots for children under the age of 5
# Expand facility 330 by 0.0 slots for all and 32.0 slots for children under the age of 5
# Expand facility 331 by 0.0 slots for all and 46.0 slots for children under the age of 5
# Expand facility 332 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 333 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 334 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 335 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 336 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 337 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 338 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 339 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 340 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 341 by 0.0 slots for all and 28.0 slots for children under the age of 5
# Expand facility 342 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 343 by 0.0 slots for all and 17.0 slots for children under the age of 5
# Expand facility 344 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 345 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 346 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 347 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 348 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 349 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 350 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 351 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 352 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 353 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 354 by 0.0 slots for all and 16.0 slots for children under the age of 5
# Expand facility 355 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 356 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 357 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 358 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 359 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 360 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 361 by 0.0 slots for all and 16.0 slots for children under the age of 5
# Expand facility 362 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 363 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 364 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 365 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 366 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 367 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 368 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 369 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 370 by 0.0 slots for all and 32.0 slots for children under the age of 5
# Expand facility 371 by 0.0 slots for all and 25.0 slots for children under the age of 5
# Expand facility 372 by 0.0 slots for all and 23.0 slots for children under the age of 5
# Expand facility 373 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 374 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 375 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 376 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 377 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 378 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 379 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 380 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 381 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 382 by 0.0 slots for all and 24.0 slots for children under the age of 5
# Expand facility 383 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 384 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 385 by 0.0 slots for all and 36.0 slots for children under the age of 5
# Expand facility 386 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 387 by 0.0 slots for all and 6.0 slots for children under the age of 5
# Expand facility 388 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 389 by 0.0 slots for all and 16.0 slots for children under the age of 5
# Expand facility 390 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 391 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 392 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 393 by 0.0 slots for all and 28.0 slots for children under the age of 5
# Expand facility 394 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 395 by 0.0 slots for all and 45.0 slots for children under the age of 5
# Expand facility 396 by 0.0 slots for all and 23.0 slots for children under the age of 5
# Expand facility 397 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 398 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 399 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 400 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 401 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 402 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 403 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 404 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 405 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 406 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 407 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 408 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 409 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 410 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 411 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 412 by 0.0 slots for all and 59.0 slots for children under the age of 5
# Expand facility 413 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 414 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 415 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 416 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 417 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 418 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 419 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 420 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 421 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 422 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 423 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 424 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 425 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 426 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 427 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 428 by 0.0 slots for all and 3.0 slots for children under the age of 5
# Expand facility 429 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 430 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 431 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 432 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 433 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 434 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 435 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 436 by 0.0 slots for all and 29.0 slots for children under the age of 5
# Expand facility 437 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 438 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 439 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 440 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 441 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 442 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 443 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 444 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 445 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 446 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 447 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 448 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 449 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 450 by 0.0 slots for all and 24.0 slots for children under the age of 5
# Expand facility 451 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 452 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 453 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 454 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 455 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 456 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 457 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 458 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 459 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 460 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 461 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 462 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 463 by 0.0 slots for all and 30.0 slots for children under the age of 5
# Expand facility 464 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 465 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 466 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 467 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 468 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 469 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 470 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 471 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 472 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 473 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 474 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 475 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 476 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 477 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 478 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 479 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 480 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 481 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 482 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 483 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 484 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 485 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 486 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 487 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 488 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 489 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 490 by 0.0 slots for all and 20.0 slots for children under the age of 5
# Expand facility 491 by 0.0 slots for all and 41.0 slots for children under the age of 5
# Expand facility 492 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 493 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 494 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 495 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 496 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 497 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 498 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 499 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 500 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 501 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 502 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 503 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 504 by 0.0 slots for all and 27.0 slots for children under the age of 5
# Expand facility 505 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 506 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 507 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 508 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 509 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 510 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 511 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 512 by 0.0 slots for all and 14.0 slots for children under the age of 5
# Expand facility 513 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 514 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 515 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 516 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 517 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 518 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 519 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 520 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 521 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 522 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 523 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 524 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 525 by 0.0 slots for all and 43.0 slots for children under the age of 5
# Expand facility 526 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 527 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 528 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 529 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 530 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 531 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 532 by 0.0 slots for all and 28.0 slots for children under the age of 5
# Expand facility 533 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 534 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 535 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 536 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 537 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 538 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 539 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 540 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 541 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 542 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 543 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 544 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 545 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 546 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 547 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 548 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 549 by 0.0 slots for all and 0.0 slots for children under the age of 5
# Expand facility 550 by 0.0 slots for all and 0.0 slots for children under the age of 5
# ...
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 13420
# Build 0.0 small,1.0 medium, 1.0 large facilities in region 13421
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 13424
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13431
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13439
# Build 0.0 small,0.0 medium, 6.0 large facilities in region 13440
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 13441
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13452
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13456
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13459
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13460
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13461
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13469
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13473
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13478
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13480
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 13490
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13491
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13492
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13495
# Build 0.0 small,0.0 medium, 6.0 large facilities in region 13501
# Build 0.0 small,0.0 medium, 6.0 large facilities in region 13502
# Build 0.0 small,0.0 medium, 4.0 large facilities in region 13601
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13605
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13606
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13608
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13612
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13613
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13616
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13617
# Build 1.0 small,0.0 medium, 1.0 large facilities in region 13619
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13620
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13622
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13624
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 13625
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13626
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 13630
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13634
# Build 1.0 small,0.0 medium, 1.0 large facilities in region 13637
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 13642
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13646
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13648
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13652
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13654
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13655
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13656
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13658
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13660
# Build 1.0 small,0.0 medium, 2.0 large facilities in region 13662
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13668
# Build 1.0 small,0.0 medium, 2.0 large facilities in region 13669
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 13672
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13673
# Build 1.0 small,0.0 medium, 1.0 large facilities in region 13676
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13685
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13691
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13694
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13730
# Build 1.0 small,0.0 medium, 1.0 large facilities in region 13732
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13733
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13739
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 13740
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13743
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13746
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13750
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13751
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13753
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13754
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13757
# Build 0.0 small,0.0 medium, 4.0 large facilities in region 13760
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 13775
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 13776
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13778
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13782
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 13783
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13787
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 13790
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13795
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13796
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13802
# Build 1.0 small,0.0 medium, 1.0 large facilities in region 13803
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13807
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13808
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13810
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13811
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13812
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 13815
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13820
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13825
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13827
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13830
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 13838
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13839
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 13842
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13849
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 13850
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 13856
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13862
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 13863
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 13864
# Build 1.0 small,0.0 medium, 1.0 large facilities in region 13865
# Build 0.0 small,0.0 medium, 3.0 large facilities in region 13901
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 13903
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 13904
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 13905
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14001
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 14004
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14005
# Build 1.0 small,0.0 medium, 1.0 large facilities in region 14006
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14009
# Build 1.0 small,0.0 medium, 1.0 large facilities in region 14011
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14012
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 14020
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14024
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 14025
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14031
# Build 0.0 small,1.0 medium, 1.0 large facilities in region 14032
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14036
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 14040
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14042
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14043
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 14047
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14048
# Build 1.0 small,0.0 medium, 2.0 large facilities in region 14051
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14052
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14057
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14058
# Build 1.0 small,0.0 medium, 1.0 large facilities in region 14059
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 14063
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 14066
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14067
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 14068
# Build 0.0 small,1.0 medium, 1.0 large facilities in region 14070
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14072
# Build 0.0 small,0.0 medium, 3.0 large facilities in region 14075
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14080
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 14081
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 14082
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14085
# Build 0.0 small,0.0 medium, 3.0 large facilities in region 14086
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14091
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14092
# Build 0.0 small,0.0 medium, 4.0 large facilities in region 14094
# Build 0.0 small,1.0 medium, 1.0 large facilities in region 14103
# Build 1.0 small,0.0 medium, 1.0 large facilities in region 14105
# Build 0.0 small,1.0 medium, 1.0 large facilities in region 14108
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14111
# Build 0.0 small,0.0 medium, 5.0 large facilities in region 14120
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14127
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 14131
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14132
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14136
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 14138
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 14141
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14145
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 14150
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 14171
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14172
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 14174
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14201
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 14202
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 14203
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14204
# Build 1.0 small,0.0 medium, 3.0 large facilities in region 14206
# Build 0.0 small,0.0 medium, 5.0 large facilities in region 14207
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14208
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 14209
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14210
# Build 0.0 small,1.0 medium, 5.0 large facilities in region 14211
# Build 0.0 small,0.0 medium, 3.0 large facilities in region 14212
# Build 0.0 small,0.0 medium, 6.0 large facilities in region 14213
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 14214
# Build 0.0 small,0.0 medium, 7.0 large facilities in region 14215
# Build 1.0 small,0.0 medium, 4.0 large facilities in region 14216
# Build 0.0 small,1.0 medium, 1.0 large facilities in region 14217
# Build 0.0 small,0.0 medium, 3.0 large facilities in region 14218
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14219
# Build 1.0 small,0.0 medium, 3.0 large facilities in region 14220
# Build 0.0 small,0.0 medium, 3.0 large facilities in region 14221
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 14222
# Build 0.0 small,0.0 medium, 3.0 large facilities in region 14223
# Build 0.0 small,0.0 medium, 3.0 large facilities in region 14224
# Build 0.0 small,0.0 medium, 4.0 large facilities in region 14225
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 14226
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 14227
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14228
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14301
# Build 0.0 small,1.0 medium, 1.0 large facilities in region 14303
# Build 0.0 small,0.0 medium, 3.0 large facilities in region 14304
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 14305
# Build 1.0 small,0.0 medium, 1.0 large facilities in region 14411
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 14414
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14416
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14420
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14423
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14424
# Build 1.0 small,0.0 medium, 2.0 large facilities in region 14425
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 14432
# Build 1.0 small,0.0 medium, 1.0 large facilities in region 14433
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14437
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14445
# Build 0.0 small,0.0 medium, 3.0 large facilities in region 14450
# Build 1.0 small,0.0 medium, 1.0 large facilities in region 14456
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 14464
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 14468
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14470
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 14472
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14476
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 14481
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 14486
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14505
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 14510
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14521
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14525
# Build 0.0 small,0.0 medium, 3.0 large facilities in region 14526
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14532
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 14536
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14541
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14544
# Build 1.0 small,0.0 medium, 1.0 large facilities in region 14546
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 14560
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 14564
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14568
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14569
# Build 0.0 small,0.0 medium, 4.0 large facilities in region 14580
# Build 0.0 small,1.0 medium, 1.0 large facilities in region 14586
# Build 0.0 small,1.0 medium, 1.0 large facilities in region 14589
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14590
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14608
# Build 0.0 small,0.0 medium, 3.0 large facilities in region 14609
# Build 1.0 small,0.0 medium, 4.0 large facilities in region 14612
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14617
# Build 0.0 small,0.0 medium, 5.0 large facilities in region 14621
# Build 0.0 small,0.0 medium, 2.0 large facilities in region 14622
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 14623
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 14625
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 14717
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14727
# Build 0.0 small,0.0 medium, 0.0 large facilities in region 14731
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14741
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14747
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14767
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14770
# Build 0.0 small,0.0 medium, 1.0 large facilities in region 14772
# Build 1.0 small,0.0 medium, 0.0 large facilities in region 14805
# Build 0.0 small,1.0 medium, 0.0 large facilities in region 14806

# %%
from geopy import distance
distance.distance((childcare["latitude"][0],childcare["longitude"][0]),(childcare["latitude"][1],childcare["longitude"][1])).miles
# Out:
# 0.09124712427874171
